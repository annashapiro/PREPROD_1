# %%
import pandas as pd
import re
from unidecode import unidecode
import numpy as np
import spacy #also necessary to have the 'packages' of Spanish and French

# %%
#!python -m spacy download es_core_news_md
#!python -m spacy download fr_core_news_md

# %%
# Load the Spanish model
nlp_es = spacy.load("es_core_news_md")

# Load the French model
nlp_fr = spacy.load("fr_core_news_md")

# %% [markdown]
# Now we load the file(s)

# %%
#name = 'The Excel_subset.xlsx' # Subset containing ~1760 answers per language
#data = pd.read_excel(name, sheet_name='Sheet1')

name = 'The Excel.xlsx' # Final data, containing ~12,000 answers per language
data = pd.read_excel(name, sheet_name='Sheet1')

# %%
data.Language.value_counts() # To see how many answers per language
# Out:
# Language
# Spanish    12528
# French     11544
# Name: count, dtype: int64

# %% [markdown]
# ### Missing data

# %%
data[data.Completion == "-"] # All missing completions
# Out:
#        Item Language Participant Group Completion  Participant      List  \
# 24033     7   French                 A          -           29  ListA.FR
# 24034    30   French                 A          -           51  ListA.FR
# 24035    30   French                 A          -           29  ListA.FR
# 24036    31   French                 A          -           29  ListA.FR
# 24037    33   French                 C          -          146  ListB.FR
# 24038    42   French                 A          -           29  ListA.FR
# 24039    48   French                 A          -           29  ListA.FR
# 24040    56   French                 A          -           55  ListB.FR
# 24041    56   French                 A          -           40  ListB.FR
# 24042    79   French                 A          -           40  ListB.FR
# 24043    97   French                 A          -           51  ListA.FR
# 24044   108   French                 A          -           55  ListB.FR
# 24045   118   French                 A          -           29  ListA.FR
# 24046   124   French                 A          -           55  ListB.FR
# 24047   140   French                 A          -           29  ListA.FR
# 24048   153   French                 A          -           42  ListC.FR
# 24049   158   French                 A          -           51  ListA.FR
# 24050   182   French                 A          -           29  ListA.FR
# 24051   184   French                 A          -            6  ListA.FR
# 24052   185   French                 A          -           55  ListB.FR
# 24053   194   French                 A          -            4  ListA.FR
# 24054   212   French                 A          -           44  ListB.FR
# 24055   219   French                 A          -           29  ListA.FR
# 24056   220   French                 A          -           44  ListB.FR
# 24057   222   French                 C          -          146  ListB.FR
# 24058   224   French                 A          -           29  ListA.FR
# 24059   229   French                 A          -           51  ListA.FR
# 24060   234   French                 A          -          200  ListB.FR
# 24061   242   French                 A          -           33  ListC.FR
# 24062   272   French                 A          -           29  ListA.FR
# 24063   274   French                 A          -           29  ListA.FR
# 24064   286   French                 A          -           29  ListA.FR
# 24065   288   French                 A          -           55  ListB.FR
# 24066   296   French                 A          -           29  ListA.FR
# 24067   305   French                 A          -           55  ListB.FR
# 24068   307   French                 A          -           29  ListA.FR
# 24069   308   French                 A          -           29  ListA.FR
# 24070   319   French                 A          -           41  ListC.FR
# 24071   186  Spanish                 A          -           33  ListB.SP
#
#        LexTALE SP  LexTALE FR Noun
# 24033   97.500000   47.321429    -
# 24034   87.500000   54.464286    -
# 24035   97.500000   47.321429    -
# 24036   97.500000   47.321429    -
# 24037    0.000000   80.357143    -
# 24038   97.500000   47.321429    -
# 24039   97.500000   47.321429    -
# 24040   96.666667   61.607143    -
# 24041   93.333333   54.464286    -
# 24042   93.333333   54.464286    -
# 24043   87.500000   54.464286    -
# 24044   96.666667   61.607143    -
# 24045   97.500000   47.321429    -
# 24046   96.666667   61.607143    -
# 24047   97.500000   47.321429    -
# 24048   98.333333   66.964286    -
# 24049   87.500000   54.464286    -
# 24050   97.500000   47.321429    -
# 24051   91.666667   56.250000    -
# 24052   96.666667   61.607143    -
# 24053   83.333333   55.357143    -
# 24054   85.000000   48.214286    -
# 24055   97.500000   47.321429    -
# 24056   85.000000   48.214286    -
# 24057    0.000000   80.357143    -
# 24058   97.500000   47.321429    -
# 24059   87.500000   54.464286    -
# 24060         NaN         NaN    -
# 24061   85.000000   64.285714    -
# 24062   97.500000   47.321429    -
# 24063   97.500000   47.321429    -
# 24064   97.500000   47.321429    -
# 24065   96.666667   61.607143    -
# 24066   97.500000   47.321429    -
# 24067   96.666667   61.607143    -
# 24068   97.500000   47.321429    -
# 24069   97.500000   47.321429    -
# 24070   96.666667   75.000000    -
# 24071   85.000000   64.285714    -

# %% [markdown]
# # Seeing raw answers

# %% [markdown]
# ### Of a specific item, in all languages

# %%
item = 35 # insert number of item

filtered_data = data[data.Item == item]

print(filtered_data)
# Out:
#        Item Language Participant Group  \
# 102      35  Spanish                 B
# 440      35  Spanish                 A
# 441      35  Spanish                 B
# 870      35  Spanish                 B
# 871      35  Spanish                 A
# ...     ...      ...               ...
# 20361    35   French                 C
# 20362    35   French                 C
# 20363    35   French                 C
# 20364    35   French                 C
# 20611    35   French                 A
#
#                                               Completion  Participant  \
# 102    el contrato de arrendamiento y recoger las lla...          102
# 440                         el contrato de arrendamiento            7
# 441                         el contrato de arrendamiento          105
# 870                              el contrato de alquiler           99
# 871                              el contrato de alquiler            5
# ...                                                  ...          ...
# 20361                                            le bail          156
# 20362                                            le bail          160
# 20363                                            le bail          151
# 20364                                            un bail          162
# 20611                                            contrat           55
#
#            List  LexTALE SP  LexTALE FR        Noun
# 102    ListB.SP   88.333333    0.000000    contrato
# 440    ListB.SP   88.333333   53.571429    contrato
# 441    ListB.SP   96.666667    0.000000    contrato
# 870    ListB.SP   96.666667    0.000000    contrato
# 871    ListB.SP   96.666667   63.392857    contrato
# ...         ...         ...         ...         ...
# 20361  ListB.FR    0.000000  100.000000        bail
# 20362  ListB.FR    0.000000   90.178571        bail
# 20363  ListB.FR    0.000000   71.428571        bail
# 20364  ListB.FR    0.000000   96.428571        bail
# 20611  ListB.FR   96.666667   61.607143  contrat(s)
#
# [70 rows x 9 columns]

# %% [markdown]
# ### Of a specific item, in a specific language

# %%
item = 30 # insert number of item
language = "French" # insert language (Spanish, French)

filtered_data = data.query('Language == @language & Item == @item')

print(filtered_data[['Completion']])
# Out:
#                     Completion
# 783    les canots de sauvetage
# 1461      la partie principale
# 2750          les embarcations
# 4420             le commandant
# 4573             les passagers
# 5374              le capitaine
# 5375              le capitaine
# 5376              le capitaine
# 5377              le capitaine
# 5378              le capitaine
# 5379              le capitaine
# 5380              le capitaine
# 5381              le capitaine
# 5382              le capitaine
# 5383              le capitaine
# 5384              le capitaine
# 5385              le capitaine
# 5386              le capitaine
# 5387              le capitaine
# 5388              le capitaine
# 5389              le capitaine
# 5390              le capitaine
# 5391              le capitaine
# 5392              le capitaine
# 7135               le capitane
# 7136               le capitane
# 7498               l' equipage
# 10223               les hommes
# 13467                de l' eau
# 13468                de l' eau
# 17393                 a la mer
# 17622                 passager
# 22630                   a flot
# 23833                     vite
# 24034                        -
# 24035                        -

# %% [markdown]
# # Cleaning answers

# %% [markdown]
# This is basically Natural Language Processing! First we define our functions, we want to remove accents, substitute special characters in Spanish and French, and remove dots:

# %%
def remove_accents(text):
    return unidecode(text)

def special_french(text):
    text = text.replace("œ", "oe")
    text = text.replace("æ", "ae")
    return text

def special_spanish(text):
    text = text.replace("ñ", "ny")
    return text

def remove_dots(text):
    return str(text).replace('.', '')

# %% [markdown]
# And we apply the functions

# %%
data['Completion'] = data['Completion'].apply(remove_dots)
data['Completion'] = data['Completion'].apply(remove_accents)
data['Completion'] = data['Completion'].apply(special_french)
data['Completion'] = data['Completion'].apply(special_spanish)

# %% [markdown]
# We add this extra line of code because we want to turn all capital letters into lower case letters:

# %%
data['Completion'] = data['Completion'].str.lower()

# %% [markdown]
# Finally, we add a space after all apostrophes to be able to split them in different words (if Python reads some text as "L'enchante" it takes is as 1 word only, we want to split it in two words) - not sure that's a French word by the way...

# %%
data['Completion'] = data['Completion'].str.replace("'", "' ")

# %% [markdown]
# # Grammatical categories of answers

# %%
df = pd.DataFrame(data) # we have to turn it into a dataframe otherwise it won't work

# %% [markdown]
# We define our function to get the first noun mentioned in the answer of participants

# %%
def get_first_noun(text, lang):
    if lang == 'es':
        doc = nlp_es(text)
    elif lang == 'fr':
        doc = nlp_fr(text)
    else:
        return None
    
    # Check if the text is a single word
    if len(doc) == 1:
        if doc[0].pos_ == 'NOUN' or (doc[0].pos_ != 'PROPN' and not doc[0].is_stop):
            return doc[0].text
    
    # Check if the text contains a noun
    has_noun = False
    for token in doc:
        if token.pos_ == 'NOUN' and not token.is_stop:
            has_noun = True
            break
    
    # If the text contains a noun
    if has_noun:
        for token in doc:
            if token.pos_ == 'NOUN' and not token.is_stop:
                return token.text
    
    return None

# %% [markdown]
# Now let's apply the function to our data:

# %%
data['Noun'] = data.apply(lambda row: get_first_noun(row['Completion'], 'es' if row['Language'] == 'Spanish' else 'fr'), axis=1)

# Print the DataFrame to verify
print(data)
# Out:
#        Item Language Participant Group  \
# 0       200  Spanish                 B
# 1       251  Spanish                 B
# 2       284   French                 A
# 3        60  Spanish                 B
# 4       236  Spanish                 B
# ...     ...      ...               ...
# 24067   305   French                 A
# 24068   307   French                 A
# 24069   308   French                 A
# 24070   319   French                 A
# 24071   186  Spanish                 A
#
#                                               Completion  Participant  \
# 0      una de las religiones mas antiguas del mundo, ...          102
# 1      un entrenador con experiencia que les ensenara...          102
# 2      son cv, mettre a jours ses competences et ses ...           52
# 3      ascensores para facilitar el acceso a los piso...          102
# 4      a un majestuoso leon descansando bajo la sombr...          102
# ...                                                  ...          ...
# 24067                                                  -           55
# 24068                                                  -           29
# 24069                                                  -           29
# 24070                                                  -           41
# 24071                                                  -           33
#
#            List  LexTALE SP  LexTALE FR        Noun
# 0      ListB.SP   88.333333    0.000000  religiones
# 1      ListB.SP   88.333333    0.000000  entrenador
# 2      ListA.FR   90.000000   86.607143          cv
# 3      ListB.SP   88.333333    0.000000  ascensores
# 4      ListB.SP   88.333333    0.000000      sombra
# ...         ...         ...         ...         ...
# 24067  ListB.FR   96.666667   61.607143           -
# 24068  ListA.FR   97.500000   47.321429           -
# 24069  ListA.FR   97.500000   47.321429           -
# 24070  ListC.FR   96.666667   75.000000           -
# 24071  ListB.SP   85.000000   64.285714           -
#
# [24072 rows x 9 columns]

# %% [markdown]
# # Summarising answers for all items

# %% [markdown]
# ## Splitting answers

# %% [markdown]
# We split the column 'Completion' into several columns, one for each word:

# %%
word_columns = data['Completion'].str.split(r"(?<=\w)\b", expand=True)
word_columns.columns = [f'word{i}' for i in range(1, word_columns.shape[1] + 1)]
data = pd.concat([data, word_columns], axis=1)

# %% [markdown]
# Some people are very creative and they write super long sentences, but we want to keep maximum 8 words:

# %%
data = data.iloc[:, :(df.shape[1]+9)]
data # to check if it worked
# Out:
#        Item Language Participant Group  \
# 0       200  Spanish                 B
# 1       251  Spanish                 B
# 2       284   French                 A
# 3        60  Spanish                 B
# 4       236  Spanish                 B
# ...     ...      ...               ...
# 24067   305   French                 A
# 24068   307   French                 A
# 24069   308   French                 A
# 24070   319   French                 A
# 24071   186  Spanish                 A
#
#                                               Completion  Participant  \
# 0      una de las religiones mas antiguas del mundo, ...          102
# 1      un entrenador con experiencia que les ensenara...          102
# 2      son cv, mettre a jours ses competences et ses ...           52
# 3      ascensores para facilitar el acceso a los piso...          102
# 4      a un majestuoso leon descansando bajo la sombr...          102
# ...                                                  ...          ...
# 24067                                                  -           55
# 24068                                                  -           29
# 24069                                                  -           29
# 24070                                                  -           41
# 24071                                                  -           33
#
#            List  LexTALE SP  LexTALE FR        Noun       word1  ...  \
# 0      ListB.SP   88.333333    0.000000  religiones         una  ...
# 1      ListB.SP   88.333333    0.000000  entrenador          un  ...
# 2      ListA.FR   90.000000   86.607143          cv         son  ...
# 3      ListB.SP   88.333333    0.000000  ascensores  ascensores  ...
# 4      ListB.SP   88.333333    0.000000      sombra           a  ...
# ...         ...         ...         ...         ...         ...  ...
# 24067  ListB.FR   96.666667   61.607143           -           -  ...
# 24068  ListA.FR   97.500000   47.321429           -           -  ...
# 24069  ListA.FR   97.500000   47.321429           -           -  ...
# 24070  ListC.FR   96.666667   75.000000           -           -  ...
# 24071  ListB.SP   85.000000   64.285714           -           -  ...
#
#             word22     word23         word24      word25 word26    word27  \
# 0              que        han   evolucionado           a     lo     largo
# 1       necesarios       para          tener       exito     en        el
# 2            poste      aquel             il   postulait             None
# 3           manera        mas    conveniente               None      None
# 4             esta   poderosa       criatura          en     su   habitat
# ...            ...        ...            ...         ...    ...       ...
# 24067         None       None           None        None   None      None
# 24068         None       None           None        None   None      None
# 24069         None       None           None        None   None      None
# 24070         None       None           None        None   None      None
# 24071         None       None           None        None   None      None
#
#          word28 word29   word30 word31
# 0            de    los   siglos
# 1         campo            None   None
# 2          None   None     None   None
# 3          None   None     None   None
# 4       natural            None   None
# ...         ...    ...      ...    ...
# 24067      None   None     None   None
# 24068      None   None     None   None
# 24069      None   None     None   None
# 24070      None   None     None   None
# 24071      None   None     None   None
#
# [24072 rows x 40 columns]

# %%
data = data.iloc[:, :(df.shape[1]+8)]

# %% [markdown]
# ## Any filters?

# %% [markdown]
# Now we are going to summarise answers! Make a copy of data to go back to if we want to delete filters:

# %%
data2 = data.copy()

# %% [markdown]
# Filtering by <strong>language</strong>

# %%
data_french = data2[(data2['Language'] == 'French')]
data_spanish = data2[(data2['Language'] == 'Spanish')]

# %% [markdown]
# Check if filtering done right, old number of lines should be larger than new number of lines if any filer was applied:

# %%
print (data.shape[0])
print (data2.shape[0])
# Out:
# 24072
# 13195

# %% [markdown]
# ## Summarising all answers (Method 1)

# %% [markdown]
# Create an empty dictionary to store word distributions for each item

# %%
word_distributions1 = {}

# %%
position = 1 # input the word position you're interested in

for item, group_df in data2.groupby('Item'):
    word_distribution = group_df['Noun'].value_counts(normalize=True) * 100
    word_distributions1[item] = word_distribution

# %%
for item, distribution in word_distributions1.items():
    print(f'Item {item} Word Distribution:')
    print(distribution)
    print()
# Out:
# Item 1 Word Distribution:
# Noun
# vacas       45.0
# vaches      40.0
# vache        7.5
# vaca         5.0
# mamelles     2.5
# Name: proportion, dtype: float64
#
# Item 2 Word Distribution:
# Noun
# examen      97.435897
# examenes     2.564103
# Name: proportion, dtype: float64
#
# Item 3 Word Distribution:
# Noun
# cenicero     55.0
# cendrier     25.0
# maison        2.5
# cendriers     2.5
# ceniciere     2.5
# cericier      2.5
# vapper        2.5
# verre         2.5
# plat          2.5
# sac           2.5
# Name: proportion, dtype: float64
#
# Item 4 Word Distribution:
# Noun
# carrera       25.0
# course        25.0
# maraton       20.0
# marathon      12.5
# sol            2.5
# campeonato     2.5
# medaille       2.5
# partido        2.5
# marche         2.5
# prix           2.5
# jeu            2.5
# Name: proportion, dtype: float64
#
# Item 5 Word Distribution:
# Noun
# sushi         64.864865
# comida        16.216216
# nourriture     2.702703
# baquettes      2.702703
# cuisine        2.702703
# repas          2.702703
# cultura        2.702703
# ramen          2.702703
# japon          2.702703
# Name: proportion, dtype: float64
#
# Item 6 Word Distribution:
# Noun
# hospital    38.235294
# hopital     14.705882
# carte        8.823529
# taxi         5.882353
# magasin      5.882353
# local        2.941176
# lieu         2.941176
# riviere      2.941176
# village      2.941176
# opticien     2.941176
# docteur      2.941176
# police       2.941176
# guide        2.941176
# ayuda        2.941176
# Name: proportion, dtype: float64
#
# Item 7 Word Distribution:
# Noun
# mermelada    45.0
# confiture    35.0
# pain          5.0
# marmelade     2.5
# mermelade     2.5
# aceite        2.5
# huile         2.5
# crema         2.5
# -             2.5
# Name: proportion, dtype: float64
#
# Item 8 Word Distribution:
# Noun
# vinaigre    43.750
# vinagre     28.125
# citron       9.375
# alino        3.125
# aceite       3.125
# salsa        3.125
# sucre        3.125
# laitue       3.125
# douce        3.125
# Name: proportion, dtype: float64
#
# Item 9 Word Distribution:
# Noun
# parque          32.258065
# parc            29.032258
# portaventura     9.677419
# espagne          3.225806
# mundo            3.225806
# monde            3.225806
# eleve            3.225806
# flags            3.225806
# eurodisney       3.225806
# alpes            3.225806
# foire            3.225806
# disney           3.225806
# Name: proportion, dtype: float64
#
# Item 10 Word Distribution:
# Noun
# lapiz           45.0
# crayon          30.0
# stylo           17.5
# calculatrice     2.5
# boligrafo        2.5
# boli             2.5
# Name: proportion, dtype: float64
#
# Item 11 Word Distribution:
# Noun
# verla             20.833333
# obra               8.333333
# estreno            8.333333
# funcion            8.333333
# soiree             4.166667
# prix               4.166667
# piece              4.166667
# debut              4.166667
# theatre            4.166667
# fonction           4.166667
# fila               4.166667
# vendredi           4.166667
# familia            4.166667
# rang               4.166667
# representation     4.166667
# connaissances      4.166667
# ambas              4.166667
# Name: proportion, dtype: float64
#
# Item 12 Word Distribution:
# Noun
# papier      42.5
# papel       37.5
# trozo        7.5
# feuille      5.0
# destreza     2.5
# practica     2.5
# ombre        2.5
# Name: proportion, dtype: float64
#
# Item 13 Word Distribution:
# Noun
# crema     51.282051
# creme     46.153846
# cremes     2.564103
# Name: proportion, dtype: float64
#
# Item 14 Word Distribution:
# Noun
# week        35.0
# semana      27.5
# viernes     17.5
# vendredi     7.5
# fin          2.5
# dimanche     2.5
# retard       2.5
# martes       2.5
# finde        2.5
# Name: proportion, dtype: float64
#
# Item 15 Word Distribution:
# Noun
# capital     51.282051
# capitale    38.461538
# c            2.564103
# amiga        2.564103
# visite       2.564103
# attente      2.564103
# Name: proportion, dtype: float64
#
# Item 16 Word Distribution:
# Noun
# boulangerie    45.0
# panaderia      45.0
# pasteleria      2.5
# chambre         2.5
# obrador         2.5
# marche          2.5
# Name: proportion, dtype: float64
#
# Item 17 Word Distribution:
# Noun
# volumen    37.5
# musique    20.0
# volume     17.5
# bruit      10.0
# musica      5.0
# douleur     2.5
# luces       2.5
# ruido       2.5
# luz         2.5
# Name: proportion, dtype: float64
#
# Item 18 Word Distribution:
# Noun
# cloches       42.5
# campanas      35.0
# campanadas     5.0
# misa           5.0
# campans        2.5
# campana        2.5
# cloche         2.5
# matine         2.5
# reloj          2.5
# Name: proportion, dtype: float64
#
# Item 19 Word Distribution:
# Noun
# ticket      66.666667
# recibo      10.256410
# billet       5.128205
# dinero       5.128205
# recu         2.564103
# paiement     2.564103
# monnaie      2.564103
# argent       2.564103
# cle          2.564103
# Name: proportion, dtype: float64
#
# Item 20 Word Distribution:
# Noun
# lista      30.0
# liste      22.5
# papel      20.0
# papier     12.5
# cahier      5.0
# feuille     5.0
# libreta     2.5
# note        2.5
# Name: proportion, dtype: float64
#
# Item 21 Word Distribution:
# Noun
# cargador     50.000000
# chargeur     42.105263
# telephone     2.631579
# bateria       2.631579
# cable         2.631579
# Name: proportion, dtype: float64
#
# Item 22 Word Distribution:
# Noun
# journal       42.857143
# transports     7.142857
# diario         7.142857
# metro          7.142857
# transporte     3.571429
# frontiere      3.571429
# portable       3.571429
# ecole          3.571429
# fabrica        3.571429
# trabajo        3.571429
# presse         3.571429
# ciudad         3.571429
# train          3.571429
# usine          3.571429
# Name: proportion, dtype: float64
#
# Item 23 Word Distribution:
# Noun
# estrella      51.282051
# etoile        38.461538
# boules         5.128205
# chandelles     2.564103
# paillettes     2.564103
# Name: proportion, dtype: float64
#
# Item 24 Word Distribution:
# Noun
# sala          37.5
# chaise        17.5
# salle         15.0
# siege          5.0
# camilla        5.0
# silla          5.0
# formulaire     2.5
# chaisse        2.5
# estancia       2.5
# canape         2.5
# brancard       2.5
# lit            2.5
# Name: proportion, dtype: float64
#
# Item 25 Word Distribution:
# Noun
# vista       47.5
# vue         32.5
# myopie       7.5
# vision       7.5
# capacite     2.5
# ojos         2.5
# Name: proportion, dtype: float64
#
# Item 26 Word Distribution:
# Noun
# libro       30.0
# livre       25.0
# livres      20.0
# libros      17.5
# bouquin      2.5
# prestamo     2.5
# nuit         2.5
# Name: proportion, dtype: float64
#
# Item 27 Word Distribution:
# Noun
# metro      77.5
# voiture    10.0
# tren        5.0
# train       2.5
# velo        2.5
# bus         2.5
# Name: proportion, dtype: float64
#
# Item 28 Word Distribution:
# Noun
# fotografia       37.5
# photo            35.0
# fotografias      10.0
# photos            7.5
# photographie      2.5
# photographies     2.5
# fotos             2.5
# video             2.5
# Name: proportion, dtype: float64
#
# Item 29 Word Distribution:
# Noun
# porte     50.0
# puerta    42.5
# llave      7.5
# Name: proportion, dtype: float64
#
# Item 30 Word Distribution:
# Noun
# capitan         46.153846
# capitaine       17.948718
# capitane         5.128205
# eau              5.128205
# -                5.128205
# canots           2.564103
# partie           2.564103
# embarcations     2.564103
# mer              2.564103
# passager         2.564103
# punta            2.564103
# flote            2.564103
# vite             2.564103
# Name: proportion, dtype: float64
#
# Item 31 Word Distribution:
# Noun
# nieve       33.333333
# neige       30.769231
# camino      10.256410
# chemin       5.128205
# sol          5.128205
# montagne     2.564103
# tierra       2.564103
# terre        2.564103
# suelo        2.564103
# bois         2.564103
# -            2.564103
# Name: proportion, dtype: float64
#
# Item 32 Word Distribution:
# Noun
# despertador    35.0
# alarme         22.5
# reveil         22.5
# alarma         15.0
# reveille        2.5
# ennuyeux        2.5
# Name: proportion, dtype: float64
#
# Item 33 Word Distribution:
# Noun
# azucar       43.589744
# sucre        41.025641
# azucarero     5.128205
# morceau       2.564103
# eau           2.564103
# doux          2.564103
# lait          2.564103
# Name: proportion, dtype: float64
#
# Item 34 Word Distribution:
# Noun
# gato     46.153846
# chat     41.025641
# chien     5.128205
# chats     2.564103
# semis     2.564103
# vivo      2.564103
# Name: proportion, dtype: float64
#
# Item 35 Word Distribution:
# Noun
# contrato     50.0
# contrat      42.5
# ecritures     2.5
# contract      2.5
# bail          2.5
# Name: proportion, dtype: float64
#
# Item 36 Word Distribution:
# Noun
# nieve     47.5
# neige     47.5
# zone       2.5
# cuesta     2.5
# Name: proportion, dtype: float64
#
# Item 37 Word Distribution:
# Noun
# noche      52.777778
# nuit       38.888889
# ecole       2.777778
# tempete     2.777778
# soir        2.777778
# Name: proportion, dtype: float64
#
# Item 38 Word Distribution:
# Noun
# guitare     45.714286
# guitarra    40.000000
# grupo        5.714286
# groupe       2.857143
# angeles      2.857143
# soirs        2.857143
# Name: proportion, dtype: float64
#
# Item 39 Word Distribution:
# Noun
# sac         45.945946
# bolso       45.945946
# boite        2.702703
# mallette     2.702703
# bolsa        2.702703
# Name: proportion, dtype: float64
#
# Item 40 Word Distribution:
# Noun
# diamante     26.086957
# bague         8.695652
# alliance      8.695652
# bijou         8.695652
# oro           8.695652
# chose         4.347826
# fleurs        4.347826
# anillo        4.347826
# diamantes     4.347826
# bracelet      4.347826
# pedrusco      4.347826
# collier       4.347826
# diamant       4.347826
# chere         4.347826
# Name: proportion, dtype: float64
#
# Item 41 Word Distribution:
# Noun
# pista         47.5
# patinoire     22.5
# restaurant     5.0
# piste          5.0
# palais         2.5
# permanence     2.5
# suite          2.5
# gymnase        2.5
# magasin        2.5
# pistes         2.5
# centro         2.5
# porte          2.5
# Name: proportion, dtype: float64
#
# Item 42 Word Distribution:
# Noun
# manta         32.5
# lit           17.5
# couverture    12.5
# cobija         5.0
# pyjama         5.0
# edredon        5.0
# draps          2.5
# cheminee       2.5
# mantita        2.5
# mantas         2.5
# drags          2.5
# robe           2.5
# sofa           2.5
# bata           2.5
# -              2.5
# Name: proportion, dtype: float64
#
# Item 43 Word Distribution:
# Noun
# fenetre     37.5
# ventana     35.0
# ventanas    15.0
# fenetres     7.5
# porte        5.0
# Name: proportion, dtype: float64
#
# Item 44 Word Distribution:
# Noun
# regalo      30.769231
# cadeau      20.512821
# gateau       7.692308
# regalos      5.128205
# tarte        2.564103
# velo         2.564103
# auto         2.564103
# reloj        2.564103
# chien        2.564103
# abrazo       2.564103
# fecha        2.564103
# balle        2.564103
# concert      2.564103
# sorpresa     2.564103
# plage        2.564103
# fiesta       2.564103
# cadeaux      2.564103
# dinero       2.564103
# Name: proportion, dtype: float64
#
# Item 45 Word Distribution:
# Noun
# lengua     38.888889
# langue     27.777778
# levres      8.333333
# labios      8.333333
# bouche      8.333333
# doute       2.777778
# paladar     2.777778
# boca        2.777778
# Name: proportion, dtype: float64
#
# Item 46 Word Distribution:
# Noun
# lune    50.0
# luna    50.0
# Name: proportion, dtype: float64
#
# Item 47 Word Distribution:
# Noun
# notredamme     25.000
# catedral       15.625
# cathedrale      9.375
# torre           6.250
# ecole           3.125
# cafe            3.125
# plaza           3.125
# ville           3.125
# tour            3.125
# ciudad          3.125
# sala            3.125
# palacio         3.125
# iglesia         3.125
# batiment        3.125
# cathedral       3.125
# supermarche     3.125
# catedrale       3.125
# camp            3.125
# Name: proportion, dtype: float64
#
# Item 48 Word Distribution:
# Noun
# reaccion      32.5
# allergie      22.5
# alergia       17.5
# reaction      12.5
# irritation     2.5
# blessure       2.5
# chirugie       2.5
# allergique     2.5
# erreur         2.5
# -              2.5
# Name: proportion, dtype: float64
#
# Item 49 Word Distribution:
# Noun
# multa            42.105263
# amende           28.947368
# voiture           5.263158
# contravention     5.263158
# grua              2.631579
# coup              2.631579
# frais             2.631579
# accidentado       2.631579
# espace            2.631579
# raya              2.631579
# roce              2.631579
# Name: proportion, dtype: float64
#
# Item 50 Word Distribution:
# Noun
# casco      50.0
# casque     47.5
# casquet     2.5
# Name: proportion, dtype: float64
#
# Item 51 Word Distribution:
# Noun
# gasolinera    50.0
# station       37.5
# route          5.0
# estation       2.5
# pompe          2.5
# zone           2.5
# Name: proportion, dtype: float64
#
# Item 52 Word Distribution:
# Noun
# tabla     84.615385
# tablas     7.692308
# table      7.692308
# Name: proportion, dtype: float64
#
# Item 53 Word Distribution:
# Noun
# agenda        43.589744
# calendario    17.948718
# calendrier    15.384615
# cahier         5.128205
# movil          5.128205
# telephone      2.564103
# ordre          2.564103
# carnet         2.564103
# portable       2.564103
# tableau        2.564103
# Name: proportion, dtype: float64
#
# Item 54 Word Distribution:
# Noun
# hijos         25.0
# enfant        12.5
# enfants       12.5
# fils           7.5
# hijo           7.5
# nietos         7.5
# perros         5.0
# chien          5.0
# bebe           5.0
# grandfils      2.5
# petit-fils     2.5
# chat           2.5
# mari           2.5
# gato           2.5
# Name: proportion, dtype: float64
#
# Item 55 Word Distribution:
# Noun
# groupe       27.5
# grupo        25.0
# banda        22.5
# bande        10.0
# orchestre     5.0
# chanson       2.5
# ensemble      2.5
# fanfare       2.5
# clases        2.5
# Name: proportion, dtype: float64
#
# Item 56 Word Distribution:
# Noun
# oportunidad         45.945946
# chance               8.108108
# opportunite          5.405405
# premio               5.405405
# prix                 5.405405
# -                    5.405405
# competition          2.702703
# applaudissements     2.702703
# erreurs              2.702703
# felicitacions        2.702703
# fois                 2.702703
# nota                 2.702703
# pluisieurs           2.702703
# gagner               2.702703
# pardon               2.702703
# Name: proportion, dtype: float64
#
# Item 57 Word Distribution:
# Noun
# rhume        21.052632
# resfriado    15.789474
# gripe        13.157895
# alergia      10.526316
# grippe        7.894737
# catarro       7.894737
# covid         5.263158
# malade        5.263158
# froid         2.631579
# allergie      2.631579
# maladie       2.631579
# probleme      2.631579
# influenza     2.631579
# Name: proportion, dtype: float64
#
# Item 58 Word Distribution:
# Noun
# moustique    35.0
# mosquito     32.5
# mosca         7.5
# abeja         5.0
# araignee      2.5
# copain        2.5
# infeccion     2.5
# voleurs       2.5
# bourdon       2.5
# ennervant     2.5
# guepe         2.5
# cosa          2.5
# Name: proportion, dtype: float64
#
# Item 59 Word Distribution:
# Noun
# nota            28.947368
# note            18.421053
# resultado       13.157895
# resultat        10.526316
# professeur       5.263158
# publication      2.631579
# calificacion     2.631579
# notes            2.631579
# resultados       2.631579
# resultats        2.631579
# notation         2.631579
# semaine          2.631579
# notas            2.631579
# radio            2.631579
# Name: proportion, dtype: float64
#
# Item 60 Word Distribution:
# Noun
# ascenseur      37.5
# ascensor       32.5
# ascensores     15.0
# ascenseurs     10.0
# garde-corps     2.5
# repisas         2.5
# Name: proportion, dtype: float64
#
# Item 61 Word Distribution:
# Noun
# mesas          37.5
# tables         32.5
# table           5.0
# canapes         5.0
# sofa            5.0
# mesa            2.5
# escritorios     2.5
# fauteuils       2.5
# tableaux        2.5
# sillones        2.5
# ecrans          2.5
# Name: proportion, dtype: float64
#
# Item 62 Word Distribution:
# Noun
# calle     42.5
# rue       32.5
# paso       2.5
# rues       2.5
# chemin     2.5
# fleuve     2.5
# puente     2.5
# herbe      2.5
# porte      2.5
# route      2.5
# acera      2.5
# pont       2.5
# Name: proportion, dtype: float64
#
# Item 63 Word Distribution:
# Noun
# alarma     25.0
# alarme     25.0
# cameras    20.0
# camaras    15.0
# camara      7.5
# camera      2.5
# cloture     2.5
# alarmas     2.5
# Name: proportion, dtype: float64
#
# Item 64 Word Distribution:
# Noun
# autografo     35.0
# autographe    25.0
# camiseta       7.5
# cd             7.5
# tee            5.0
# disco          5.0
# chanson        2.5
# albums         2.5
# album          2.5
# disque         2.5
# photo          2.5
# cul            2.5
# Name: proportion, dtype: float64
#
# Item 65 Word Distribution:
# Noun
# match      43.589744
# partido    41.025641
# finale      2.564103
# equipo      2.564103
# espagne     2.564103
# derby       2.564103
# estadio     2.564103
# partie      2.564103
# Name: proportion, dtype: float64
#
# Item 66 Word Distribution:
# Noun
# zumo     46.153846
# jus      46.153846
# jugo      5.128205
# verre     2.564103
# Name: proportion, dtype: float64
#
# Item 67 Word Distribution:
# Noun
# tumba       57.142857
# tombeau     10.714286
# mari         7.142857
# defunt       3.571429
# lapida       3.571429
# cercueil     3.571429
# pierre       3.571429
# ataud        3.571429
# nicho        3.571429
# sol          3.571429
# Name: proportion, dtype: float64
#
# Item 68 Word Distribution:
# Noun
# espada     36.842105
# epee       31.578947
# florete    10.526316
# feuille     2.631579
# fleuret     2.631579
# epees       2.631579
# florin      2.631579
# excel       2.631579
# sabre       2.631579
# sable       2.631579
# crayon      2.631579
# Name: proportion, dtype: float64
#
# Item 69 Word Distribution:
# Noun
# loup    75.000000
# lobo    20.833333
# ami      4.166667
# Name: proportion, dtype: float64
#
# Item 70 Word Distribution:
# Noun
# ventana      35.0
# fenetre      32.5
# ventanas     15.0
# fenetres     15.0
# fenestres     2.5
# Name: proportion, dtype: float64
#
# Item 71 Word Distribution:
# Noun
# pala        46.153846
# pelle       41.025641
# tableaux     2.564103
# pico         2.564103
# chemin       2.564103
# arbre        2.564103
# terre        2.564103
# Name: proportion, dtype: float64
#
# Item 72 Word Distribution:
# Noun
# disco           37.837838
# album           21.621622
# disque          18.918919
# nom              2.702703
# documentaire     2.702703
# discos           2.702703
# chanson          2.702703
# musique          2.702703
# cd               2.702703
# lp               2.702703
# rock             2.702703
# Name: proportion, dtype: float64
#
# Item 73 Word Distribution:
# Noun
# excusa      45.945946
# excuse      40.540541
# maladie      5.405405
# enferma      2.702703
# histoire     2.702703
# pretexto     2.702703
# Name: proportion, dtype: float64
#
# Item 74 Word Distribution:
# Noun
# cesta            17.857143
# corral           10.714286
# poulailler       10.714286
# panier            7.142857
# poules            7.142857
# poulet            3.571429
# sac               3.571429
# paniers           3.571429
# poele             3.571429
# granja            3.571429
# refrigerateur     3.571429
# poule             3.571429
# enclos            3.571429
# establo           3.571429
# canasta           3.571429
# bergerie          3.571429
# gallinero         3.571429
# huile             3.571429
# Name: proportion, dtype: float64
#
# Item 75 Word Distribution:
# Noun
# rueda     45.0
# roue      40.0
# motor      5.0
# roues      2.5
# llanta     2.5
# cycle      2.5
# rue        2.5
# Name: proportion, dtype: float64
#
# Item 76 Word Distribution:
# Noun
# porte     50.0
# puerta    47.5
# acaso      2.5
# Name: proportion, dtype: float64
#
# Item 77 Word Distribution:
# Noun
# maison      43.589744
# casa        25.641026
# chalet      12.820513
# terrain      5.128205
# chale        5.128205
# columpio     2.564103
# chien        2.564103
# juguetes     2.564103
# Name: proportion, dtype: float64
#
# Item 78 Word Distribution:
# Noun
# ciudad    51.282051
# ville     46.153846
# centre     2.564103
# Name: proportion, dtype: float64
#
# Item 79 Word Distribution:
# Noun
# monja          47.058824
# nonne          17.647059
# musulmana       8.823529
# religieuse      5.882353
# enterrement     2.941176
# chretienne      2.941176
# voisine         2.941176
# religiosa       2.941176
# gothique        2.941176
# musulman        2.941176
# -               2.941176
# Name: proportion, dtype: float64
#
# Item 80 Word Distribution:
# Noun
# piscine    48.717949
# piscina    48.717949
# spa         2.564103
# Name: proportion, dtype: float64
#
# Item 81 Word Distribution:
# Noun
# cuadrado    40.0
# carre       32.5
# dessin       5.0
# esquema      2.5
# dibujo       2.5
# chanson      2.5
# diagrama     2.5
# cahier       2.5
# tabla        2.5
# cadre        2.5
# logo         2.5
# carree       2.5
# Name: proportion, dtype: float64
#
# Item 82 Word Distribution:
# Noun
# question     30.0
# pregunta     27.5
# duda         22.5
# doute         7.5
# questions     2.5
# demande       2.5
# demander      2.5
# pays          2.5
# fini          2.5
# Name: proportion, dtype: float64
#
# Item 83 Word Distribution:
# Noun
# calle        40.0
# rue          35.0
# route        12.5
# carretera    10.0
# passage       2.5
# Name: proportion, dtype: float64
#
# Item 84 Word Distribution:
# Noun
# journal     37.5
# diario      32.5
# libreta      7.5
# cahier       7.5
# cuaderno     7.5
# cahiere      2.5
# diare        2.5
# libro        2.5
# Name: proportion, dtype: float64
#
# Item 85 Word Distribution:
# Noun
# jardin        32.352941
# campo         17.647059
# holanda       11.764706
# champagnes     2.941176
# printemps      2.941176
# chambre        2.941176
# champs         2.941176
# cuisine        2.941176
# chemin         2.941176
# primavera      2.941176
# herbe          2.941176
# principe       2.941176
# salon          2.941176
# prado          2.941176
# valle          2.941176
# vase           2.941176
# Name: proportion, dtype: float64
#
# Item 86 Word Distribution:
# Noun
# vaso         20.0
# eau          20.0
# agua         15.0
# verre        12.5
# botella       7.5
# biere         7.5
# boisson       5.0
# coca          5.0
# batido        2.5
# bouteille     2.5
# cana          2.5
# Name: proportion, dtype: float64
#
# Item 87 Word Distribution:
# Noun
# boligrafo    33.333333
# stylo        15.384615
# crayon       12.820513
# lapiz        12.820513
# ecrire        7.692308
# nom           5.128205
# histoire      2.564103
# nombres       2.564103
# examen        2.564103
# escribir      2.564103
# biro          2.564103
# Name: proportion, dtype: float64
#
# Item 88 Word Distribution:
# Noun
# gateau        15.0
# cadeau        12.5
# pastel        12.5
# bizcocho      12.5
# tarte         10.0
# tarta         10.0
# galletas       7.5
# biscuits       5.0
# regalo         5.0
# plaisir        2.5
# chocolates     2.5
# carte          2.5
# gateux         2.5
# Name: proportion, dtype: float64
#
# Item 89 Word Distribution:
# Noun
# horno        46.153846
# four         38.461538
# feu           7.692308
# casserole     2.564103
# frigo         2.564103
# fuego         2.564103
# Name: proportion, dtype: float64
#
# Item 90 Word Distribution:
# Noun
# calabaza       30.0
# citrouille     25.0
# calabazas      20.0
# citrouilles    12.5
# courge          5.0
# courges         2.5
# portes          2.5
# calebasse       2.5
# Name: proportion, dtype: float64
#
# Item 91 Word Distribution:
# Noun
# levadura       43.589744
# levure         38.461538
# ingredient      2.564103
# polvo           2.564103
# temperature     2.564103
# ingrediente     2.564103
# farine          2.564103
# levain          2.564103
# oeufs           2.564103
# Name: proportion, dtype: float64
#
# Item 92 Word Distribution:
# Noun
# receta           48.717949
# recette          35.897436
# videos            2.564103
# instrucciones     2.564103
# consignes         2.564103
# mange             2.564103
# blog              2.564103
# malade            2.564103
# Name: proportion, dtype: float64
#
# Item 93 Word Distribution:
# Noun
# trapo         20.0
# pano          15.0
# chiffon       12.5
# serviette      7.5
# torchon        7.5
# bayeta         7.5
# tissu          7.5
# papier         5.0
# estropajo      2.5
# servilleta     2.5
# guenille       2.5
# vetement       2.5
# balleta        2.5
# eponge         2.5
# tapis          2.5
# Name: proportion, dtype: float64
#
# Item 94 Word Distribution:
# Noun
# mancha     33.333333
# tache      30.769231
# manchas    17.948718
# sale        5.128205
# reduit      2.564103
# taches      2.564103
# manche      2.564103
# chemise     2.564103
# sali        2.564103
# Name: proportion, dtype: float64
#
# Item 95 Word Distribution:
# Noun
# bufanda     42.5
# echarpe     25.0
# manteau     15.0
# foulard      7.5
# palteau      2.5
# chaqueta     2.5
# campera      2.5
# abrigo       2.5
# Name: proportion, dtype: float64
#
# Item 96 Word Distribution:
# Noun
# manzana    50.0
# pomme      42.5
# miroir      2.5
# vie         2.5
# mort        2.5
# Name: proportion, dtype: float64
#
# Item 97 Word Distribution:
# Noun
# terremoto      44.736842
# seisme         18.421053
# tremblement     7.894737
# temblement      2.631579
# desgracia       2.631579
# accident        2.631579
# terremot        2.631579
# guerre          2.631579
# tsunami         2.631579
# chute           2.631579
# caida           2.631579
# peril           2.631579
# robo            2.631579
# -               2.631579
# Name: proportion, dtype: float64
#
# Item 98 Word Distribution:
# Noun
# trophee     28.205128
# trofeo      17.948718
# copa        12.820513
# premio      10.256410
# medalla      7.692308
# prix         7.692308
# medaille     5.128205
# coupe        5.128205
# balon        2.564103
# argent       2.564103
# Name: proportion, dtype: float64
#
# Item 99 Word Distribution:
# Noun
# figura        15.789474
# figure        13.157895
# figuritas     13.157895
# figurine      10.526316
# poupees        5.263158
# figuras        5.263158
# ornement       5.263158
# figurita       5.263158
# figurines      5.263158
# personnage     2.631579
# fiances        2.631579
# figures        2.631579
# pareja         2.631579
# flores         2.631579
# drapeau        2.631579
# maries         2.631579
# vela           2.631579
# Name: proportion, dtype: float64
#
# Item 100 Word Distribution:
# Noun
# ballon      46.153846
# ballons     23.076923
# globos      23.076923
# balloons     3.846154
# globe        3.846154
# Name: proportion, dtype: float64
#
# Item 101 Word Distribution:
# Noun
# boton               34.285714
# bouton              22.857143
# boutons             11.428571
# botones              8.571429
# boutton              5.714286
# concienzudamente     2.857143
# cremallera           2.857143
# fil                  2.857143
# rapidement           2.857143
# fermeture            2.857143
# main                 2.857143
# Name: proportion, dtype: float64
#
# Item 102 Word Distribution:
# Noun
# grill          30.0
# fromage        25.0
# queso           7.5
# oeuf            7.5
# papel           5.0
# horno           5.0
# bechamel        5.0
# mantequilla     2.5
# aceite          2.5
# temperature     2.5
# temperatura     2.5
# capa            2.5
# fonction        2.5
# Name: proportion, dtype: float64
#
# Item 103 Word Distribution:
# Noun
# scalpel     55.0
# bistouri    15.0
# ciseaux     10.0
# coupeur      5.0
# couteau      5.0
# cutter       5.0
# pince        5.0
# Name: proportion, dtype: float64
#
# Item 104 Word Distribution:
# Noun
# toalla        45.0
# serviette     42.5
# secador        5.0
# serviettes     2.5
# peignoir       2.5
# sechoir        2.5
# Name: proportion, dtype: float64
#
# Item 105 Word Distribution:
# Noun
# flor      50.0
# fleur     37.5
# fleure     7.5
# plante     5.0
# Name: proportion, dtype: float64
#
# Item 106 Word Distribution:
# Noun
# cartera         38.461538
# portefeuille    33.333333
# sac              5.128205
# billetera        5.128205
# monedero         5.128205
# voiture          2.564103
# interior         2.564103
# argent           2.564103
# livre            2.564103
# largent          2.564103
# Name: proportion, dtype: float64
#
# Item 107 Word Distribution:
# Noun
# ventana     40.0
# fenetre     37.5
# fenetres    12.5
# ventanas    10.0
# Name: proportion, dtype: float64
#
# Item 108 Word Distribution:
# Noun
# fuente       41.025641
# fontaine     17.948718
# bar           5.128205
# eau           5.128205
# maquina       2.564103
# bouteille     2.564103
# bol           2.564103
# bebedero      2.564103
# glacier       2.564103
# source        2.564103
# tienda        2.564103
# fleuve        2.564103
# herbe         2.564103
# cafe          2.564103
# pave          2.564103
# -             2.564103
# Name: proportion, dtype: float64
#
# Item 109 Word Distribution:
# Noun
# dedo      45.945946
# doigt     40.540541
# main       5.405405
# bout       2.702703
# mano       2.702703
# indice     2.702703
# Name: proportion, dtype: float64
#
# Item 110 Word Distribution:
# Noun
# puente     40.0
# pont       30.0
# bateau      7.5
# riviere     5.0
# barca       5.0
# fleuve      2.5
# canot       2.5
# ponte       2.5
# nadando     2.5
# nado        2.5
# Name: proportion, dtype: float64
#
# Item 111 Word Distribution:
# Noun
# tarjeta    50.0
# carte      37.5
# credit      2.5
# compte      2.5
# argent      2.5
# card        2.5
# visa        2.5
# Name: proportion, dtype: float64
#
# Item 112 Word Distribution:
# Noun
# relacion        45.714286
# relation        28.571429
# habitudes        2.857143
# conversation     2.857143
# discussion       2.857143
# phrases          2.857143
# silence          2.857143
# amour            2.857143
# danse            2.857143
# rutinas          2.857143
# lazos            2.857143
# Name: proportion, dtype: float64
#
# Item 113 Word Distribution:
# Noun
# queso       45.0
# fromage     42.5
# produits     2.5
# fromages     2.5
# frommage     2.5
# helado       2.5
# crema        2.5
# Name: proportion, dtype: float64
#
# Item 114 Word Distribution:
# Noun
# garage     51.282051
# garaje     43.589744
# entrada     5.128205
# Name: proportion, dtype: float64
#
# Item 115 Word Distribution:
# Noun
# concierto    58.823529
# concert      38.235294
# salzburg      2.941176
# Name: proportion, dtype: float64
#
# Item 116 Word Distribution:
# Noun
# message     47.5
# mensaje     47.5
# mensajes     2.5
# photo        2.5
# Name: proportion, dtype: float64
#
# Item 117 Word Distribution:
# Noun
# restaurante    51.282051
# restaurant     46.153846
# bistro          2.564103
# Name: proportion, dtype: float64
#
# Item 118 Word Distribution:
# Noun
# bano      45.0
# bain      40.0
# bulles     2.5
# soleil     2.5
# ducha      2.5
# spa        2.5
# chaud      2.5
# -          2.5
# Name: proportion, dtype: float64
#
# Item 119 Word Distribution:
# Noun
# fe            51.282051
# foi           43.589744
# desir          2.564103
# motivation     2.564103
# Name: proportion, dtype: float64
#
# Item 120 Word Distribution:
# Noun
# table       47.5
# mesa        47.5
# couverts     2.5
# platos       2.5
# Name: proportion, dtype: float64
#
# Item 121 Word Distribution:
# Noun
# muneca      50.0
# poupee      47.5
# poupette     2.5
# Name: proportion, dtype: float64
#
# Item 122 Word Distribution:
# Noun
# chat          27.777778
# gato          25.000000
# chien         13.888889
# perrito       11.111111
# perro          5.555556
# animal         2.777778
# cachorrito     2.777778
# peluche        2.777778
# gatito         2.777778
# lapin          2.777778
# amour          2.777778
# Name: proportion, dtype: float64
#
# Item 123 Word Distribution:
# Noun
# avion        26.470588
# vol          11.764706
# taxi         11.764706
# vuelo         8.823529
# clase         8.823529
# aerolinea     5.882353
# lufthansa     5.882353
# viaje         2.941176
# option        2.941176
# compania      2.941176
# airlines      2.941176
# metro         2.941176
# train         2.941176
# ryanair       2.941176
# Name: proportion, dtype: float64
#
# Item 124 Word Distribution:
# Noun
# cactus        71.052632
# plant          2.631579
# planta         2.631579
# sante          2.631579
# orquidea       2.631579
# decorative     2.631579
# resistente     2.631579
# roses          2.631579
# pins           2.631579
# pousser        2.631579
# couper         2.631579
# -              2.631579
# Name: proportion, dtype: float64
#
# Item 125 Word Distribution:
# Noun
# coeur      75.0
# cerebro    10.0
# corazon     5.0
# poumon      5.0
# peau        5.0
# Name: proportion, dtype: float64
#
# Item 126 Word Distribution:
# Noun
# llave     42.857143
# llaves    28.571429
# cle       25.000000
# carte      3.571429
# Name: proportion, dtype: float64
#
# Item 127 Word Distribution:
# Noun
# playa     47.5
# plage     42.5
# sable      5.0
# orilla     2.5
# rive       2.5
# Name: proportion, dtype: float64
#
# Item 128 Word Distribution:
# Noun
# barbe       46.153846
# barba       46.153846
# mananas      2.564103
# cheveaux     2.564103
# visage       2.564103
# Name: proportion, dtype: float64
#
# Item 129 Word Distribution:
# Noun
# pie       35.0
# peau      22.5
# pied      20.0
# planta     7.5
# pieds      2.5
# pierna     2.5
# jambe      2.5
# talon      2.5
# poid       2.5
# piel       2.5
# Name: proportion, dtype: float64
#
# Item 130 Word Distribution:
# Noun
# cuchillo    50.0
# couteau     50.0
# Name: proportion, dtype: float64
#
# Item 131 Word Distribution:
# Noun
# coupe      47.619048
# trophee    28.571429
# bras        9.523810
# fuerzas     4.761905
# brazos      4.761905
# diner       4.761905
# Name: proportion, dtype: float64
#
# Item 132 Word Distribution:
# Noun
# corona      50.0
# couronne    50.0
# Name: proportion, dtype: float64
#
# Item 133 Word Distribution:
# Noun
# lavadora         47.5
# machine          35.0
# lave              5.0
# blanchisserie     2.5
# linge             2.5
# laveuse           2.5
# cesto             2.5
# laver             2.5
# Name: proportion, dtype: float64
#
# Item 134 Word Distribution:
# Noun
# beso          43.589744
# bisou         25.641026
# baiser         5.128205
# cadeau         5.128205
# gifle          5.128205
# embrassade     2.564103
# engueulade     2.564103
# bofetada       2.564103
# tortazo        2.564103
# argent         2.564103
# besos          2.564103
# Name: proportion, dtype: float64
#
# Item 135 Word Distribution:
# Noun
# television    68.181818
# radio         27.272727
# feu            4.545455
# Name: proportion, dtype: float64
#
# Item 136 Word Distribution:
# Noun
# ovni               71.794872
# nave                7.692308
# alien               5.128205
# soucoupe            2.564103
# extraterrestres     2.564103
# aventure            2.564103
# cohete              2.564103
# cometa              2.564103
# dragon              2.564103
# Name: proportion, dtype: float64
#
# Item 137 Word Distribution:
# Noun
# escultura       16.216216
# obra            10.810811
# cuadro           8.108108
# sculpture        8.108108
# exposee          5.405405
# cadre            5.405405
# visite           2.702703
# preciosa         2.702703
# protegee         2.702703
# tableau          2.702703
# statue           2.702703
# magnifique       2.702703
# estatua          2.702703
# celebre          2.702703
# entree           2.702703
# sculture         2.702703
# peinture         2.702703
# merveilleuse     2.702703
# piece            2.702703
# ecran            2.702703
# atraccion        2.702703
# oeuvre           2.702703
# espectacular     2.702703
# Name: proportion, dtype: float64
#
# Item 138 Word Distribution:
# Noun
# luz          48.717949
# lumiere      25.641026
# lumieres     12.820513
# lampe         7.692308
# alumbrado     2.564103
# lume          2.564103
# Name: proportion, dtype: float64
#
# Item 139 Word Distribution:
# Noun
# loteria     44.736842
# loterie     28.947368
# loto         7.894737
# bourse       5.263158
# sorteo       2.631579
# travail      2.631579
# banque       2.631579
# investir     2.631579
# rapide       2.631579
# Name: proportion, dtype: float64
#
# Item 140 Word Distribution:
# Noun
# tasse        42.5
# taza         37.5
# merienda      2.5
# tardes        2.5
# marruecos     2.5
# tase          2.5
# caliente      2.5
# verre         2.5
# tazas         2.5
# -             2.5
# Name: proportion, dtype: float64
#
# Item 141 Word Distribution:
# Noun
# ambulancia    46.153846
# ambulance     35.897436
# vite           5.128205
# urgencia       2.564103
# voiture        2.564103
# policia        2.564103
# rapide         2.564103
# peur           2.564103
# Name: proportion, dtype: float64
#
# Item 142 Word Distribution:
# Noun
# neige        54.545455
# nieve        21.212121
# carretera     6.060606
# asfalto       6.060606
# accidente     3.030303
# causa         3.030303
# endroits      3.030303
# circuler      3.030303
# Name: proportion, dtype: float64
#
# Item 143 Word Distribution:
# Noun
# gripe        47.5
# grippe       40.0
# influenza     5.0
# covid19       2.5
# covid         2.5
# rhume         2.5
# Name: proportion, dtype: float64
#
# Item 144 Word Distribution:
# Noun
# chaise        40.0
# silla         30.0
# taburete      20.0
# canape         5.0
# restaurant     2.5
# tabouret       2.5
# Name: proportion, dtype: float64
#
# Item 145 Word Distribution:
# Noun
# arbre       32.5
# arbol       32.5
# arbres      10.0
# pino         7.5
# pinos        5.0
# arboles      2.5
# pins         2.5
# manzanos     2.5
# plantes      2.5
# pin          2.5
# Name: proportion, dtype: float64
#
# Item 146 Word Distribution:
# Noun
# arroz      43.589744
# riz        38.461538
# soja        7.692308
# sauce       2.564103
# poisson     2.564103
# pescado     2.564103
# humide      2.564103
# Name: proportion, dtype: float64
#
# Item 147 Word Distribution:
# Noun
# batterie    45.0
# bateria     32.5
# piano       17.5
# tambour      2.5
# saxofon      2.5
# Name: proportion, dtype: float64
#
# Item 148 Word Distribution:
# Noun
# beso      51.282051
# bisou     28.205128
# baiser     7.692308
# bise       5.128205
# fleur      2.564103
# paton      2.564103
# main       2.564103
# Name: proportion, dtype: float64
#
# Item 149 Word Distribution:
# Noun
# botella      44.444444
# bouteille    19.444444
# verre        16.666667
# pack          2.777778
# boutelle      2.777778
# botellas      2.777778
# escoces       2.777778
# gorgee        2.777778
# coctel        2.777778
# coupe         2.777778
# Name: proportion, dtype: float64
#
# Item 150 Word Distribution:
# Noun
# cafe         82.5
# boisson       2.5
# aspirina      2.5
# cocacola      2.5
# descanso      2.5
# cafes         2.5
# vitaminas     2.5
# bull          2.5
# Name: proportion, dtype: float64
#
# Item 151 Word Distribution:
# Noun
# cancion     47.5
# chanson     40.0
# dedicace     2.5
# lettre       2.5
# piece        2.5
# poeme        2.5
# poema        2.5
# Name: proportion, dtype: float64
#
# Item 152 Word Distribution:
# Noun
# prison           48.571429
# carcel           42.857143
# maison            2.857143
# carte             2.857143
# correctionnel     2.857143
# Name: proportion, dtype: float64
#
# Item 153 Word Distribution:
# Noun
# club           51.428571
# equipe          5.714286
# ecole           5.714286
# groupe          5.714286
# equipo          5.714286
# deportes        2.857143
# jeux            2.857143
# personnes       2.857143
# association     2.857143
# federation      2.857143
# gymnase         2.857143
# waterpolo       2.857143
# baile           2.857143
# -               2.857143
# Name: proportion, dtype: float64
#
# Item 154 Word Distribution:
# Noun
# cuisine    50.0
# cocina     50.0
# Name: proportion, dtype: float64
#
# Item 155 Word Distribution:
# Noun
# corbata         44.736842
# cravate         26.315789
# chapeau          5.263158
# zapatos          5.263158
# correctement     2.631579
# cordones         2.631579
# couture          2.631579
# corbat           2.631579
# valise           2.631579
# camisa           2.631579
# bras             2.631579
# Name: proportion, dtype: float64
#
# Item 156 Word Distribution:
# Noun
# croix    62.068966
# cruz     34.482759
# amour     3.448276
# Name: proportion, dtype: float64
#
# Item 157 Word Distribution:
# Noun
# cuchillo     51.282051
# couteau      46.153846
# assasinat     2.564103
# Name: proportion, dtype: float64
#
# Item 158 Word Distribution:
# Noun
# cuento       30.0
# cuentos      17.5
# conte        15.0
# histoire     12.5
# histoires    12.5
# nuit          5.0
# contes        2.5
# nana          2.5
# -             2.5
# Name: proportion, dtype: float64
#
# Item 159 Word Distribution:
# Noun
# sport         50.0
# deporte       47.5
# disciplina     2.5
# Name: proportion, dtype: float64
#
# Item 160 Word Distribution:
# Noun
# fuego            47.5
# feu              32.5
# consideration     2.5
# incendios         2.5
# proprietes        2.5
# reputation        2.5
# resultats         2.5
# liquide           2.5
# vitamin           2.5
# saveur            2.5
# Name: proportion, dtype: float64
#
# Item 161 Word Distribution:
# Noun
# horno       46.153846
# four        41.025641
# eau          5.128205
# fourneau     2.564103
# refrito      2.564103
# feu          2.564103
# Name: proportion, dtype: float64
#
# Item 162 Word Distribution:
# Noun
# cielo             48.717949
# ciel              15.384615
# paradis           10.256410
# reconnaissance     5.128205
# place              2.564103
# enterrement        2.564103
# reencarnation      2.564103
# respect            2.564103
# recompense         2.564103
# eternite           2.564103
# paraiso            2.564103
# rien               2.564103
# Name: proportion, dtype: float64
#
# Item 163 Word Distribution:
# Noun
# juez        51.282051
# juge        41.025641
# jugement     2.564103
# proces       2.564103
# jury         2.564103
# Name: proportion, dtype: float64
#
# Item 164 Word Distribution:
# Noun
# llave        44.117647
# cle          38.235294
# cerrajero     5.882353
# llaves        5.882353
# coup          2.941176
# palanca       2.941176
# Name: proportion, dtype: float64
#
# Item 165 Word Distribution:
# Noun
# mechero       35.897436
# briquet       25.641026
# feu           12.820513
# encendedor     7.692308
# match          5.128205
# allumettes     2.564103
# briquete       2.564103
# matches        2.564103
# mecehero       2.564103
# cerillas       2.564103
# Name: proportion, dtype: float64
#
# Item 166 Word Distribution:
# Noun
# memoire         45.0
# memoria         35.0
# conocimiento    10.0
# consciencia      5.0
# orientation      2.5
# conscience       2.5
# Name: proportion, dtype: float64
#
# Item 167 Word Distribution:
# Noun
# journal       68.181818
# periodicos     4.545455
# journaux       4.545455
# noticias       4.545455
# courant        4.545455
# magasin        4.545455
# nouvelles      4.545455
# diario         4.545455
# Name: proportion, dtype: float64
#
# Item 168 Word Distribution:
# Noun
# piano          75.0
# violin         17.5
# violon          2.5
# violoncelle     2.5
# flauta          2.5
# Name: proportion, dtype: float64
#
# Item 169 Word Distribution:
# Noun
# piel    51.282051
# peau    43.589744
# yeux     5.128205
# Name: proportion, dtype: float64
#
# Item 170 Word Distribution:
# Noun
# jambe      30.0
# pierna     30.0
# tibia       7.5
# bras        7.5
# jambes      5.0
# brazo       5.0
# femur       5.0
# neige       2.5
# rodilla     2.5
# genou       2.5
# os          2.5
# Name: proportion, dtype: float64
#
# Item 171 Word Distribution:
# Noun
# piramide      42.5
# pyramide      27.5
# pyramides      7.5
# piramides      5.0
# tumba          5.0
# sarcophage     2.5
# chateaux       2.5
# sarcofago      2.5
# templo         2.5
# tombes         2.5
# Name: proportion, dtype: float64
#
# Item 172 Word Distribution:
# Noun
# piscina      48.717949
# piscine      43.589744
# baignoire     2.564103
# ans           2.564103
# ducha         2.564103
# Name: proportion, dtype: float64
#
# Item 173 Word Distribution:
# Noun
# pluma     42.5
# plume     37.5
# hoja       5.0
# fleur      2.5
# oiseau     2.5
# soeur      2.5
# mere       2.5
# vent       2.5
# aire       2.5
# Name: proportion, dtype: float64
#
# Item 174 Word Distribution:
# Noun
# regalo     45.0
# cadeau     42.5
# gateau      5.0
# cadeaux     2.5
# tarta       2.5
# regalos     2.5
# Name: proportion, dtype: float64
#
# Item 175 Word Distribution:
# Noun
# sello        48.717949
# timbre       38.461538
# direction     2.564103
# remitente     2.564103
# adresse       2.564103
# cachet        2.564103
# joint         2.564103
# Name: proportion, dtype: float64
#
# Item 176 Word Distribution:
# Noun
# taxi      90.0
# padre      5.0
# pareja     2.5
# uber       2.5
# Name: proportion, dtype: float64
#
# Item 177 Word Distribution:
# Noun
# taza          48.571429
# tasse         34.285714
# pot            8.571429
# tasses         2.857143
# sous-tasse     2.857143
# verre          2.857143
# Name: proportion, dtype: float64
#
# Item 178 Word Distribution:
# Noun
# television    68.0
# tele          16.0
# lumiere        8.0
# televiseur     4.0
# televisor      4.0
# Name: proportion, dtype: float64
#
# Item 179 Word Distribution:
# Noun
# tesoro    86.363636
# tresor     4.545455
# norte      4.545455
# ile        4.545455
# Name: proportion, dtype: float64
#
# Item 180 Word Distribution:
# Noun
# tour     51.282051
# torre    48.717949
# Name: proportion, dtype: float64
#
# Item 181 Word Distribution:
# Noun
# tunel       35.897436
# tunnel      25.641026
# pont         7.692308
# riviere      5.128205
# puente       5.128205
# route        5.128205
# estacion     2.564103
# camino       2.564103
# pueblo       2.564103
# foret        2.564103
# peage        2.564103
# taxe         2.564103
# Name: proportion, dtype: float64
#
# Item 182 Word Distribution:
# Noun
# ducha        37.5
# douche       35.0
# bano         12.5
# -             5.0
# eau           5.0
# serviette     2.5
# froid         2.5
# Name: proportion, dtype: float64
#
# Item 183 Word Distribution:
# Noun
# vent      45.0
# viento    45.0
# rafale     2.5
# aires      2.5
# pluie      2.5
# aire       2.5
# Name: proportion, dtype: float64
#
# Item 184 Word Distribution:
# Noun
# marcapaginas    44.444444
# separador        5.555556
# livre            5.555556
# souvenir         5.555556
# marcador         5.555556
# liseuse          2.777778
# camera           2.777778
# signet           2.777778
# disque           2.777778
# carte            2.777778
# maison           2.777778
# etagere          2.777778
# truc             2.777778
# chemise          2.777778
# chose            2.777778
# marque-page      2.777778
# -                2.777778
# Name: proportion, dtype: float64
#
# Item 185 Word Distribution:
# Noun
# pupila      40.540541
# pupille     18.918919
# yeux        16.216216
# pupilas      8.108108
# pupilles     5.405405
# lunettes     2.702703
# eleve        2.702703
# ici          2.702703
# -            2.702703
# Name: proportion, dtype: float64
#
# Item 186 Word Distribution:
# Noun
# tinta         47.5
# encre         35.0
# c              2.5
# erreur         2.5
# indelebile     2.5
# permanent      2.5
# ecrire         2.5
# casse          2.5
# -              2.5
# Name: proportion, dtype: float64
#
# Item 187 Word Distribution:
# Noun
# paraguas     50.0
# parapluie    42.5
# courses       2.5
# parkas        2.5
# refuge        2.5
# Name: proportion, dtype: float64
#
# Item 188 Word Distribution:
# Noun
# bateria      47.5
# batterie     42.5
# baterie       5.0
# batteries     2.5
# motor         2.5
# Name: proportion, dtype: float64
#
# Item 189 Word Distribution:
# Noun
# aceite       34.375
# poele        15.625
# huile        15.625
# casserole    12.500
# beurre        6.250
# sarten        3.125
# eau           3.125
# oeil          3.125
# fort          3.125
# haut          3.125
# Name: proportion, dtype: float64
#
# Item 190 Word Distribution:
# Noun
# termometro     54.838710
# thermometre    22.580645
# mano            9.677419
# bains           3.225806
# medicaments     3.225806
# medicament      3.225806
# medicine        3.225806
# Name: proportion, dtype: float64
#
# Item 191 Word Distribution:
# Noun
# ciel          46.153846
# cielo         46.153846
# firmamento     5.128205
# telescope      2.564103
# Name: proportion, dtype: float64
#
# Item 192 Word Distribution:
# Noun
# arc-en-ciel    70.588235
# sol            11.764706
# ciel            5.882353
# pluie           5.882353
# cielo           5.882353
# Name: proportion, dtype: float64
#
# Item 193 Word Distribution:
# Noun
# bougies       27.5
# vela          22.5
# velas         20.0
# bougie         7.5
# chandelles     5.0
# chandelle      2.5
# ballons        2.5
# velitas        2.5
# pequeno        2.5
# velita         2.5
# voile          2.5
# bugies         2.5
# Name: proportion, dtype: float64
#
# Item 194 Word Distribution:
# Noun
# chocolate    50.0
# chocolat     37.5
# farine        5.0
# beurre        2.5
# harine        2.5
# -             2.5
# Name: proportion, dtype: float64
#
# Item 195 Word Distribution:
# Noun
# sistema     33.333333
# systeme     28.205128
# voie        10.256410
# universo     7.692308
# espacio      7.692308
# universe     2.564103
# lactea       2.564103
# espace       2.564103
# livres       2.564103
# ciel         2.564103
# Name: proportion, dtype: float64
#
# Item 196 Word Distribution:
# Noun
# dolor         46.153846
# douleur       41.025641
# mal            2.564103
# souffrance     2.564103
# dolores        2.564103
# cabeza         2.564103
# bientot        2.564103
# Name: proportion, dtype: float64
#
# Item 197 Word Distribution:
# Noun
# clignotant       35.0
# indicateur       10.0
# radios            5.0
# lumiere           5.0
# marche            5.0
# vitesse           5.0
# intermittente     5.0
# accelerateur      5.0
# clignotants       5.0
# clignotante       5.0
# len               5.0
# clignonant        5.0
# frein             5.0
# Name: proportion, dtype: float64
#
# Item 198 Word Distribution:
# Noun
# dessert      25.641026
# postre       23.076923
# tarta        15.384615
# gateau        7.692308
# flan          5.128205
# pain          2.564103
# tarte         2.564103
# croissant     2.564103
# chocolat      2.564103
# pudding       2.564103
# chocolate     2.564103
# pastel        2.564103
# bollo         2.564103
# helado        2.564103
# Name: proportion, dtype: float64
#
# Item 199 Word Distribution:
# Noun
# accident      47.5
# accidente     45.0
# an             2.5
# emergencia     2.5
# trafico        2.5
# Name: proportion, dtype: float64
#
# Item 200 Word Distribution:
# Noun
# religion    100.0
# Name: proportion, dtype: float64
#
# Item 201 Word Distribution:
# Noun
# zanahoria     37.5
# carotte       37.5
# zanahorias    10.0
# carottes       7.5
# carrotte       2.5
# vegetales      2.5
# carot          2.5
# Name: proportion, dtype: float64
#
# Item 202 Word Distribution:
# Noun
# pulpo         51.282051
# pieuvre       23.076923
# poulpe        10.256410
# mort           5.128205
# souffrance     2.564103
# dangereaux     2.564103
# octopus        2.564103
# ...
# toit          2.5
# piso          2.5
# Name: proportion, dtype: float64
#
# Item 278 Word Distribution:
# Noun
# four         13.157895
# feu          13.157895
# bougie       10.526316
# estufa       10.526316
# fuego        10.526316
# horno         7.894737
# cheminee      5.263158
# chimenea      5.263158
# vela          5.263158
# pechugas      2.631579
# chauffage     2.631579
# lumieres      2.631579
# cendres       2.631579
# brasero       2.631579
# caldera       2.631579
# gas           2.631579
# Name: proportion, dtype: float64
#
# Item 279 Word Distribution:
# Noun
# cuerda      40.0
# corde       35.0
# cuerdas      7.5
# cordes       7.5
# guitarra     2.5
# guitare      2.5
# main         2.5
# pleurer      2.5
# Name: proportion, dtype: float64
#
# Item 280 Word Distribution:
# Noun
# agujeros         33.333333
# trous            22.222222
# trou              8.333333
# manchas           5.555556
# taches            5.555556
# poubelle          2.777778
# chemise           2.777778
# piece             2.777778
# botones           2.777778
# couleur           2.777778
# deterioration     2.777778
# agujero           2.777778
# remiendos         2.777778
# arrugas           2.777778
# Name: proportion, dtype: float64
#
# Item 281 Word Distribution:
# Noun
# asiento         50.000000
# hauteur          8.823529
# siege            8.823529
# ceinture         5.882353
# volante          5.882353
# retroviseurs     2.941176
# cinturon         2.941176
# passagers        2.941176
# pedales          2.941176
# routes           2.941176
# chaise           2.941176
# place            2.941176
# Name: proportion, dtype: float64
#
# Item 282 Word Distribution:
# Noun
# casa           30.555556
# maison         30.555556
# propiedad       8.333333
# oncle           2.777778
# caserio         2.777778
# appartement     2.777778
# chalets         2.777778
# bungalow        2.777778
# terreno         2.777778
# manoir          2.777778
# bien            2.777778
# terre           2.777778
# finca           2.777778
# piso            2.777778
# Name: proportion, dtype: float64
#
# Item 283 Word Distribution:
# Noun
# suelo        35.897436
# sol          28.205128
# escaleras    10.256410
# escaliers     5.128205
# escalier      2.564103
# escalera      2.564103
# terrain       2.564103
# canape        2.564103
# terre         2.564103
# table         2.564103
# fondo         2.564103
# mur           2.564103
# Name: proportion, dtype: float64
#
# Item 284 Word Distribution:
# Noun
# curriculum     40.0
# cv             30.0
# experiencia     5.0
# reunion         2.5
# pueblo          2.5
# entretien       2.5
# entrevue        2.5
# ordenador       2.5
# resume          2.5
# cursus          2.5
# linkedin        2.5
# examens         2.5
# moverse         2.5
# Name: proportion, dtype: float64
#
# Item 285 Word Distribution:
# Noun
# salade      50.0
# ensalada    47.5
# comida       2.5
# Name: proportion, dtype: float64
#
# Item 286 Word Distribution:
# Noun
# souvenir     28.571429
# souvenirs    28.571429
# valise        8.571429
# maleta        5.714286
# chose         2.857143
# postales      2.857143
# sac           2.857143
# obsequio      2.857143
# recuerdo      2.857143
# suvenir       2.857143
# recuerdos     2.857143
# caja          2.857143
# maletas       2.857143
# -             2.857143
# Name: proportion, dtype: float64
#
# Item 287 Word Distribution:
# Noun
# muela               33.333333
# dents               12.820513
# muelas              12.820513
# molaire              7.692308
# dent                 7.692308
# chirurgicalement     2.564103
# dentiste             2.564103
# soportes             2.564103
# machoire             2.564103
# cavite               2.564103
# douleur              2.564103
# meules               2.564103
# diente               2.564103
# meule                2.564103
# dientes              2.564103
# Name: proportion, dtype: float64
#
# Item 288 Word Distribution:
# Noun
# carril      27.272727
# piste       15.151515
# trottoir    12.121212
# derecha     12.121212
# route        9.090909
# sol          6.060606
# campagne     3.030303
# roues        3.030303
# asphalte     3.030303
# selle        3.030303
# pedales      3.030303
# -            3.030303
# Name: proportion, dtype: float64
#
# Item 289 Word Distribution:
# Noun
# error      45.0
# erreur     25.0
# erreurs    15.0
# errores     5.0
# exam        2.5
# fallo       2.5
# mauvais     2.5
# mal         2.5
# Name: proportion, dtype: float64
#
# Item 290 Word Distribution:
# Noun
# dos         50.0
# espalda     47.5
# lumbares     2.5
# Name: proportion, dtype: float64
#
# Item 291 Word Distribution:
# Noun
# bolsas      25.0
# bolsa       22.5
# sacs        17.5
# sac         17.5
# bourse       5.0
# compteur     2.5
# chariot      2.5
# panier       2.5
# poche        2.5
# carro        2.5
# Name: proportion, dtype: float64
#
# Item 292 Word Distribution:
# Noun
# coucher       29.729730
# puesta        16.216216
# sol           16.216216
# soleil        10.810811
# atardecer     10.810811
# anochecer      5.405405
# caida          2.702703
# crepuscule     2.702703
# mer            2.702703
# azul           2.702703
# Name: proportion, dtype: float64
#
# Item 293 Word Distribution:
# Noun
# raquette       46.153846
# raqueta        43.589744
# uniforme        2.564103
# equipements     2.564103
# playeras        2.564103
# rackets         2.564103
# Name: proportion, dtype: float64
#
# Item 294 Word Distribution:
# Noun
# basura      47.5
# poubelle    27.5
# dechets     15.0
# meubles      2.5
# choses       2.5
# pierre       2.5
# basur        2.5
# Name: proportion, dtype: float64
#
# Item 295 Word Distribution:
# Noun
# ecole         34.285714
# colegio       31.428571
# escuela        8.571429
# college        8.571429
# lycee          5.714286
# universite     2.857143
# empresa        2.857143
# faculte        2.857143
# piscine        2.857143
# Name: proportion, dtype: float64
#
# Item 296 Word Distribution:
# Noun
# foret            44.0
# bosque            8.0
# bois              8.0
# debut             8.0
# demi              4.0
# ilustraciones     4.0
# imaginacion       4.0
# histoire          4.0
# parque            4.0
# nuit              4.0
# rue               4.0
# -                 4.0
# Name: proportion, dtype: float64
#
# Item 297 Word Distribution:
# Noun
# alfombra       44.736842
# tapis          23.684211
# chaises         2.631579
# lumieres        2.631579
# projecteurs     2.631579
# ensemble        2.631579
# scenario        2.631579
# trofeos         2.631579
# theatre         2.631579
# etape           2.631579
# podium          2.631579
# etage           2.631579
# parquet         2.631579
# moqueta         2.631579
# Name: proportion, dtype: float64
#
# Item 298 Word Distribution:
# Noun
# dessin       45.0
# dibujo       20.0
# casa         12.5
# peinture      2.5
# megalodon     2.5
# paredes       2.5
# paisaje       2.5
# cuadro        2.5
# payaso        2.5
# coche         2.5
# pared         2.5
# dessins       2.5
# Name: proportion, dtype: float64
#
# Item 299 Word Distribution:
# Noun
# couleur      36.111111
# color        36.111111
# peau          8.333333
# tamano        5.555556
# lacouleur     2.777778
# piel          2.777778
# animaux       2.777778
# aspecto       2.777778
# taille        2.777778
# Name: proportion, dtype: float64
#
# Item 300 Word Distribution:
# Noun
# baston       24.324324
# andador      24.324324
# canne        10.810811
# chaise        5.405405
# silla         5.405405
# bequilles     5.405405
# futeille      2.702703
# bequille      2.702703
# taca          2.702703
# baton         2.702703
# caddy         2.702703
# marcheur      2.702703
# batons        2.702703
# muletas       2.702703
# aide          2.702703
# Name: proportion, dtype: float64
#
# Item 301 Word Distribution:
# Noun
# aventura    28.571429
# affaire     22.857143
# amante      14.285714
# relacion     8.571429
# affair       5.714286
# trabajo      5.714286
# romance      5.714286
# femme        2.857143
# amoureux     2.857143
# menti        2.857143
# Name: proportion, dtype: float64
#
# Item 302 Word Distribution:
# Noun
# pelea        33.333333
# lutte        16.666667
# discusion     8.333333
# problemes     5.555556
# dispute       5.555556
# conflit       5.555556
# combats       5.555556
# mundo         2.777778
# ambiance      2.777778
# probleme      2.777778
# bronca        2.777778
# raison        2.777778
# bruit         2.777778
# peleas        2.777778
# Name: proportion, dtype: float64
#
# Item 303 Word Distribution:
# Noun
# rien       36.363636
# palabra    24.242424
# mot        21.212121
# mu         18.181818
# Name: proportion, dtype: float64
#
# Item 304 Word Distribution:
# Noun
# tableau      44.736842
# pizarra      36.842105
# ardoise       7.894737
# encerado      2.631579
# tablero       2.631579
# mayuscula     2.631579
# cursiva       2.631579
# Name: proportion, dtype: float64
#
# Item 305 Word Distribution:
# Noun
# lana          25.714286
# pelote        11.428571
# laine         11.428571
# pelotes        5.714286
# ballon         5.714286
# ovillos        5.714286
# balle          5.714286
# fil            2.857143
# rollo          2.857143
# hilo           2.857143
# etamine        2.857143
# rouleau        2.857143
# estambre       2.857143
# nourriture     2.857143
# zapatillas     2.857143
# bola           2.857143
# -              2.857143
# Name: proportion, dtype: float64
#
# Item 306 Word Distribution:
# Noun
# cometa      43.589744
# cerf        23.076923
# comete      20.512821
# cometas      5.128205
# feuilles     2.564103
# jouet        2.564103
# hojas        2.564103
# Name: proportion, dtype: float64
#
# Item 307 Word Distribution:
# Noun
# cinturon      30.000000
# taille        23.333333
# ceinture      13.333333
# talla         10.000000
# pantalons      6.666667
# otres          3.333333
# cinturones     3.333333
# correa         3.333333
# cinto          3.333333
# -              3.333333
# Name: proportion, dtype: float64
#
# Item 308 Word Distribution:
# Noun
# escoba         45.0
# balai          30.0
# serpilliere     5.0
# chaussures      2.5
# brosse          2.5
# escobon         2.5
# fregona         2.5
# camera          2.5
# velo            2.5
# main            2.5
# -               2.5
# Name: proportion, dtype: float64
#
# Item 309 Word Distribution:
# Noun
# augmentation    34.285714
# aumento         34.285714
# vacances         5.714286
# hausse           5.714286
# boursement       2.857143
# recompensa       2.857143
# heures           2.857143
# salaire          2.857143
# paga             2.857143
# vacaciones       2.857143
# propina          2.857143
# Name: proportion, dtype: float64
#
# Item 310 Word Distribution:
# Noun
# pesadilla     46.153846
# cauchemar     15.384615
# sieste         7.692308
# bruit          5.128205
# devoirs        2.564103
# nuit           2.564103
# sueno          2.564103
# mal            2.564103
# pesadillas     2.564103
# crise          2.564103
# voyage         2.564103
# glace          2.564103
# lit            2.564103
# pipi           2.564103
# Name: proportion, dtype: float64
#
# Item 311 Word Distribution:
# Noun
# chien       40.540541
# perro       13.513514
# canne        8.108108
# baston       8.108108
# nieta        5.405405
# femme        5.405405
# cuidador     2.702703
# andador      2.702703
# perros       2.702703
# nieto        2.702703
# tacataca     2.702703
# hija         2.702703
# hijo         2.702703
# Name: proportion, dtype: float64
#
# Item 312 Word Distribution:
# Noun
# barbecue    20.0
# grill       20.0
# parrilla    16.0
# poele        8.0
# parrille     4.0
# grille       4.0
# jardin       4.0
# asador       4.0
# horno        4.0
# feu          4.0
# plats        4.0
# salsa        4.0
# roti         4.0
# Name: proportion, dtype: float64
#
# Item 313 Word Distribution:
# Noun
# canasta     35.897436
# panier      25.641026
# bolsa        5.128205
# centre       2.564103
# domain       2.564103
# maison       2.564103
# papelera     2.564103
# taquilla     2.564103
# canaste      2.564103
# chambre      2.564103
# coffret      2.564103
# ecole        2.564103
# cesta        2.564103
# toit         2.564103
# sac          2.564103
# aro          2.564103
# Name: proportion, dtype: float64
#
# Item 314 Word Distribution:
# Noun
# ciudad        26.315789
# ville         18.421053
# carte         13.157895
# mapa          13.157895
# plan           5.263158
# quartier       5.263158
# app            2.631579
# navegation     2.631579
# navigateur     2.631579
# evenement      2.631579
# pueblo         2.631579
# concreto       2.631579
# guia           2.631579
# Name: proportion, dtype: float64
#
# Item 315 Word Distribution:
# Noun
# dieta            40.000000
# regime           20.000000
# sport             5.714286
# gimnasio          5.714286
# gymnase           5.714286
# deporte           5.714286
# programme         2.857143
# salle             2.857143
# nutricionista     2.857143
# dietista          2.857143
# fame              2.857143
# gym               2.857143
# Name: proportion, dtype: float64
#
# Item 316 Word Distribution:
# Noun
# tortilla    53.846154
# omelette    35.897436
# salade       2.564103
# gateau       2.564103
# tarte        2.564103
# plat         2.564103
# Name: proportion, dtype: float64
#
# Item 317 Word Distribution:
# Noun
# sable     46.153846
# arena     46.153846
# cubo       2.564103
# rivage     2.564103
# hijos      2.564103
# Name: proportion, dtype: float64
#
# Item 318 Word Distribution:
# Noun
# percha      41.025641
# cintre      20.512821
# cintres     10.256410
# place        2.564103
# hueco        2.564103
# perchas      2.564103
# boutons      2.564103
# perchero     2.564103
# ceintre      2.564103
# crochet      2.564103
# perche       2.564103
# pinces       2.564103
# cle          2.564103
# lieu         2.564103
# Name: proportion, dtype: float64
#
# Item 319 Word Distribution:
# Noun
# tondeuse        56.521739
# cesped          13.043478
# coupe-herbes     4.347826
# cotacesped       4.347826
# jardinier        4.347826
# action           4.347826
# coupeur          4.347826
# machine          4.347826
# -                4.347826
# Name: proportion, dtype: float64
#
# Item 320 Word Distribution:
# Noun
# nudo        51.282051
# noeud       46.153846
# attacher     2.564103
# Name: proportion, dtype: float64
#
# Item 321 Word Distribution:
# Noun
# oignon        42.307692
# cebollas      19.230769
# oignons       15.384615
# onions         7.692308
# oignions       3.846154
# finalement     3.846154
# cebolla        3.846154
# amer           3.846154
# Name: proportion, dtype: float64
#
# Item 322 Word Distribution:
# Noun
# escoba        40.0
# balai         30.0
# cueilleur      5.0
# lunettes       2.5
# cabine         2.5
# serpillere     2.5
# aspirateur     2.5
# aspirador      2.5
# chiffon        2.5
# cepillo        2.5
# pelle          2.5
# ayuda          2.5
# pan            2.5
# Name: proportion, dtype: float64
#
# Item 323 Word Distribution:
# Noun
# banco        42.105263
# banque       36.842105
# compte       10.526316
# ahorro        2.631579
# bouteille     2.631579
# tableau       2.631579
# cajero        2.631579
# Name: proportion, dtype: float64
#
# Item 324 Word Distribution:
# Noun
# code          24.0
# clave         16.0
# numero        16.0
# pin           16.0
# argent         8.0
# codigo         8.0
# mot            8.0
# contrasena     4.0
# Name: proportion, dtype: float64
#
# Item 325 Word Distribution:
# Noun
# contrato    45.0
# journee     15.0
# contrat     10.0
# jour         5.0
# reunion      5.0
# semaine      5.0
# periode      2.5
# midi         2.5
# trabajo      2.5
# saison       2.5
# annee        2.5
# beca         2.5
# Name: proportion, dtype: float64
#
# Item 326 Word Distribution:
# Noun
# huevo          40.0
# oeuf           22.5
# nid            10.0
# estufa          5.0
# place           2.5
# casserole       2.5
# calefaction     2.5
# plante          2.5
# pollito         2.5
# oiseau          2.5
# termo           2.5
# feu             2.5
# chaud           2.5
# Name: proportion, dtype: float64
#
# Item 327 Word Distribution:
# Noun
# sourire     31.578947
# sonrisa     28.947368
# visage       7.894737
# louvre       5.263158
# mirada       5.263158
# mona         2.631579
# jour         2.631579
# sourise      2.631579
# artista      2.631579
# rostro       2.631579
# tamano       2.631579
# yeux         2.631579
# distinto     2.631579
# Name: proportion, dtype: float64
#
# Item 328 Word Distribution:
# Noun
# zapato       47.5
# chaussure    42.5
# soulier       5.0
# zapatos       2.5
# talon         2.5
# Name: proportion, dtype: float64
#
# Item 329 Word Distribution:
# Noun
# maleta     45.0
# valise     40.0
# voiture     5.0
# coffre      5.0
# mochila     2.5
# valija      2.5
# Name: proportion, dtype: float64
#
# Item 330 Word Distribution:
# Noun
# delfin        35.897436
# poisson       17.948718
# dauphin       12.820513
# pez           10.256410
# saumon         5.128205
# grenouille     2.564103
# baleine        2.564103
# delphine       2.564103
# ballena        2.564103
# tiburon        2.564103
# requin         2.564103
# ours           2.564103
# Name: proportion, dtype: float64

# %% [markdown]
# ## Getting most likely answer (Method 2)

# %% [markdown]
# To get a data frame with the most-likely continuation, create a list to store the most likely continuations:

# %%
word_distributions2 = []
word_distributions3 = []

# %% [markdown]
# ### French

# %%
for item, group_df in data_french.groupby('Item'):
    # For every unique completion, calculate its probability
    word_distributionFR = group_df[f'Noun'].value_counts(normalize=True) * 100
    # Only keep the word with the biggest probability
    most_likely_wordFR = word_distributionFR.idxmax()
    probabilityFR = word_distributionFR[most_likely_wordFR]
    word_distributions2.append([item, most_likely_wordFR, probabilityFR])

# %%
results_french = pd.DataFrame(word_distributions2, columns=['Item', 'Most Likely Word', 'Probability'])

# High cloze: probability over 50%
# Note: should be 60-80% in line with literature
results_french = results_french.query('Probability >= 50')

# %% [markdown]
# ### Spanish

# %%
for item, group_df in data_spanish.groupby('Item'):
    word_distributionES = group_df[f'Noun'].value_counts(normalize=True) * 100
    most_likely_wordES = word_distributionES.idxmax()
    probabilityES = word_distributionES[most_likely_wordES]
    word_distributions3.append([item, most_likely_wordES, probabilityES])

# %%
results_spanish = pd.DataFrame(word_distributions3, columns=['Item', 'Most Likely Word', 'Probability'])
results_spanish = results_spanish.query('Probability >= 50')

# %% [markdown]
# # Final completions
# 1) Items which are over specified probability percentage in both languages

# %%
results = results_french.merge(results_spanish, left_on = 'Item', right_on = 'Item')

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Item                227 non-null    int64
#  1   Most Likely Word_x  227 non-null    object
#  2   Probability_x       227 non-null    float64
#  3   Most Likely Word_y  227 non-null    object
#  4   Probability_y       227 non-null    float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 9.0+ KB

# %% [markdown]
# 2) Items that are over 50% Cloze in French but not in Spanish

# %%
cloze_onlyfrench = set(results_french['Item']).difference(set(results_spanish['Item']))
results_frenchonly = results_french.loc[results_french['Item'].isin(cloze_onlyfrench)]

# %%
3) Items that are over 50% Cloze in Spanish but not in French

# %%
cloze_onlyspanish = set(results_spanish['Item']).difference(set(results_french['Item']))
results_spanishonly = results_spanish.loc[results_spanish['Item'].isin(cloze_onlyspanish)]

# %% [markdown]
# Creating spreadsheets

# %%
results.to_excel('clozeresults.xlsx')
results_french.to_excel('results_french.xlsx')
results_frenchonly.to_excel('results_frenchonly.xlsx')
results_spanishonly.to_excel('results_spanishonly.xlsx')
